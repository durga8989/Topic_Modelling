# %% [markdown]
# ## Problem Statement
#
# You need to build a model that is able to classify customer complaints based on the products/services. By doing so, you can segregate these tickets into their relevant categories and, therefore, help in the quick resolution of the issue.
#
# You will be doing topic modelling on the <b>.json</b> data provided by the company. Since this data is not labelled, you need to apply NMF to analyse patterns and classify tickets into the following five clusters based on their products/services:
#
# * Credit card / Prepaid card
#
# * Bank account services
#
# * Theft/Dispute reporting
#
# * Mortgages/loans
#
# * Others
#
#
# With the help of topic modelling, you will be able to map each ticket onto its respective department/category. You can then use this data to train any supervised model such as logistic regression, decision tree or random forest. Using this trained model, you can classify any new customer complaint support ticket into its relevant department.

# %% [markdown]
# ## Pipelines that needs to be performed:
#
# You need to perform the following eight major tasks to complete the assignment:
#
# 1.  Data loading
#
# 2. Text preprocessing
#
# 3. Exploratory data analysis (EDA)
#
# 4. Feature extraction
#
# 5. Topic modelling
#
# 6. Model building using supervised learning
#
# 7. Model training and evaluation
#
# 8. Model inference

# %% [markdown]
# ## Importing the necessary libraries

# %%
import json 
import numpy as np
import pandas as pd
import re, nltk, spacy, string
import en_core_web_sm
nlp = en_core_web_sm.load()
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from plotly.offline import plot
import plotly.graph_objects as go
import plotly.express as px

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pprint import pprint

# %% [markdown]
# ## Loading the data
#
# The data is in JSON format and we need to convert it to a dataframe.

# %%
# Opening JSON file 
f = open('complaints-2021-05-14_08_16.json',)# Write the path to your data file and load it 
  
# returns JSON object as  
# a dictionary 
data = json.load(f)
df=pd.json_normalize(data)

# %%
df.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state  ... _source.company_response  \
# 0  2019-04-13T12:00:00-05:00            CA  ...  Closed with explanation
# 1  2019-05-01T12:00:00-05:00            GA  ...  Closed with explanation
# 2  2019-04-02T12:00:00-05:00            TX  ...  Closed with explanation
# 3  2017-09-13T12:00:00-05:00            MI  ...  Closed with explanation
# 4  2019-04-05T12:00:00-05:00            NY  ...  Closed with explanation
#
#         _source.company _source.submitted_via _source.date_sent_to_company  \
# 0  JPMORGAN CHASE & CO.                   Web    2019-04-13T12:00:00-05:00
# 1  JPMORGAN CHASE & CO.                   Web    2019-05-01T12:00:00-05:00
# 2  JPMORGAN CHASE & CO.                   Web    2019-04-02T12:00:00-05:00
# 3  JPMORGAN CHASE & CO.                   Web    2017-09-14T12:00:00-05:00
# 4  JPMORGAN CHASE & CO.              Referral    2019-04-05T12:00:00-05:00
#
#   _source.company_public_response                         _source.sub_product  \
# 0                            None                            Credit card debt
# 1                            None                            Credit card debt
# 2                            None  General-purpose credit card or charge card
# 3                            None                  Conventional home mortgage
# 4                            None  General-purpose credit card or charge card
#
#   _source.timely                    _source.complaint_what_happened  \
# 0            Yes
# 1            Yes  Good morning my name is XXXX XXXX and I apprec...
# 2            Yes  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3            Yes
# 4            Yes
#
#                                   _source.sub_issue  \
# 0                                 Debt is not yours
# 1  Didn't receive enough information to verify debt
# 2             Problem with rewards from credit card
# 3                                              None
# 4                         Charged too much interest
#
#   _source.consumer_consent_provided
# 0              Consent not provided
# 1                  Consent provided
# 2                  Consent provided
# 3              Consent not provided
# 4                               N/A
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Data preparation

# %%
# Inspect the dataframe to understand the given data.
print("Shape of the dataframe:", df.shape)
# Out:
# Shape of the dataframe: (78313, 22)

# %%
#print the column names
for col in df.columns:
    print(col)
# Out:
# _index
# _type
# _id
# _score
# _source.tags
# _source.zip_code
# _source.complaint_id
# _source.issue
# _source.date_received
# _source.state
# _source.consumer_disputed
# _source.product
# _source.company_response
# _source.company
# _source.submitted_via
# _source.date_sent_to_company
# _source.company_public_response
# _source.sub_product
# _source.timely
# _source.complaint_what_happened
# _source.sub_issue
# _source.consumer_consent_provided

# %%
#Assign new column names
df.rename(columns={'_index':'index',
                   '_type':'type',
                   '_id':'id',
                   '_score':'score',
                   '_source.tags':'tags',
                   '_source.zip_code':'zip_code',
                   '_source.complaint_id':'complaint_id',
                   '_source.issue':'issue',
                   '_source.date_received':'date_received',
                   '_source.state':'state',
                   '_source.consumer_disputed':'consumer_disputed',
                   '_source.product':'product',
                   '_source.company_response':'company_response',
                   '_source.company':'company',
                   '_source.submitted_via':'submitted_via',
                   '_source.date_sent_to_company':'date_sent_to_company',
                   '_source.company_public_response':'company_public_response',
                   '_source.sub_product':'sub_product',
                   '_source.timely':'timely',
                   '_source.complaint_what_happened':'complaint_what_happened',
                   '_source.sub_issue':'sub_issue',
                   '_source.consumer_consent_provided':'consumer_consent_provided'
                  }, inplace=True)

# %%
df.head()
# Out:
#                  index       type       id  score           tags zip_code  \
# 0  complaint-public-v2  complaint  3211475    0.0           None    90301
# 1  complaint-public-v2  complaint  3229299    0.0  Servicemember    319XX
# 2  complaint-public-v2  complaint  3199379    0.0           None    77069
# 3  complaint-public-v2  complaint  2673060    0.0           None    48066
# 4  complaint-public-v2  complaint  3203545    0.0           None    10473
#
#   complaint_id                               issue              date_received  \
# 0      3211475   Attempts to collect debt not owed  2019-04-13T12:00:00-05:00
# 1      3229299     Written notification about debt  2019-05-01T12:00:00-05:00
# 2      3199379  Other features, terms, or problems  2019-04-02T12:00:00-05:00
# 3      2673060      Trouble during payment process  2017-09-13T12:00:00-05:00
# 4      3203545                    Fees or interest  2019-04-05T12:00:00-05:00
#
#   state  ...         company_response               company submitted_via  \
# 0    CA  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 1    GA  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 2    TX  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 3    MI  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 4    NY  ...  Closed with explanation  JPMORGAN CHASE & CO.      Referral
#
#         date_sent_to_company company_public_response  \
# 0  2019-04-13T12:00:00-05:00                    None
# 1  2019-05-01T12:00:00-05:00                    None
# 2  2019-04-02T12:00:00-05:00                    None
# 3  2017-09-14T12:00:00-05:00                    None
# 4  2019-04-05T12:00:00-05:00                    None
#
#                                   sub_product timely  \
# 0                            Credit card debt    Yes
# 1                            Credit card debt    Yes
# 2  General-purpose credit card or charge card    Yes
# 3                  Conventional home mortgage    Yes
# 4  General-purpose credit card or charge card    Yes
#
#                              complaint_what_happened  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                                           sub_issue consumer_consent_provided
# 0                                 Debt is not yours      Consent not provided
# 1  Didn't receive enough information to verify debt          Consent provided
# 2             Problem with rewards from credit card          Consent provided
# 3                                              None      Consent not provided
# 4                         Charged too much interest                       N/A
#
# [5 rows x 22 columns]

# %%
#Count blank counts in complaint column
#Out of total 78313 rows, blank complaints count is 57241
len(df[df['complaint_what_happened'] == ''])
# Out:
# 57241

# %%
#Assign nan in place of blanks in the complaints column
df['complaint_what_happened'] = df['complaint_what_happened'].replace(r'', np.NaN)
df.head(5)
# Out:
#                  index       type       id  score           tags zip_code  \
# 0  complaint-public-v2  complaint  3211475    0.0           None    90301
# 1  complaint-public-v2  complaint  3229299    0.0  Servicemember    319XX
# 2  complaint-public-v2  complaint  3199379    0.0           None    77069
# 3  complaint-public-v2  complaint  2673060    0.0           None    48066
# 4  complaint-public-v2  complaint  3203545    0.0           None    10473
#
#   complaint_id                               issue              date_received  \
# 0      3211475   Attempts to collect debt not owed  2019-04-13T12:00:00-05:00
# 1      3229299     Written notification about debt  2019-05-01T12:00:00-05:00
# 2      3199379  Other features, terms, or problems  2019-04-02T12:00:00-05:00
# 3      2673060      Trouble during payment process  2017-09-13T12:00:00-05:00
# 4      3203545                    Fees or interest  2019-04-05T12:00:00-05:00
#
#   state  ...         company_response               company submitted_via  \
# 0    CA  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 1    GA  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 2    TX  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 3    MI  ...  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 4    NY  ...  Closed with explanation  JPMORGAN CHASE & CO.      Referral
#
#         date_sent_to_company company_public_response  \
# 0  2019-04-13T12:00:00-05:00                    None
# 1  2019-05-01T12:00:00-05:00                    None
# 2  2019-04-02T12:00:00-05:00                    None
# 3  2017-09-14T12:00:00-05:00                    None
# 4  2019-04-05T12:00:00-05:00                    None
#
#                                   sub_product timely  \
# 0                            Credit card debt    Yes
# 1                            Credit card debt    Yes
# 2  General-purpose credit card or charge card    Yes
# 3                  Conventional home mortgage    Yes
# 4  General-purpose credit card or charge card    Yes
#
#                              complaint_what_happened  \
# 0                                                NaN
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3                                                NaN
# 4                                                NaN
#
#                                           sub_issue consumer_consent_provided
# 0                                 Debt is not yours      Consent not provided
# 1  Didn't receive enough information to verify debt          Consent provided
# 2             Problem with rewards from credit card          Consent provided
# 3                                              None      Consent not provided
# 4                         Charged too much interest                       N/A
#
# [5 rows x 22 columns]

# %%
#Remove all rows where complaints column is nan
df = df[pd.notnull(df['complaint_what_happened'])]
df.shape
# Out:
# (21072, 22)

# %%
df.head()
# Out:
#                   index       type       id  score           tags zip_code  \
# 1   complaint-public-v2  complaint  3229299    0.0  Servicemember    319XX
# 2   complaint-public-v2  complaint  3199379    0.0           None    77069
# 10  complaint-public-v2  complaint  3233499    0.0           None    104XX
# 11  complaint-public-v2  complaint  3180294    0.0           None    750XX
# 14  complaint-public-v2  complaint  3224980    0.0           None    920XX
#
#    complaint_id                                 issue  \
# 1       3229299       Written notification about debt
# 2       3199379    Other features, terms, or problems
# 10      3233499  Incorrect information on your report
# 11      3180294  Incorrect information on your report
# 14      3224980                   Managing an account
#
#                 date_received state  ...         company_response  \
# 1   2019-05-01T12:00:00-05:00    GA  ...  Closed with explanation
# 2   2019-04-02T12:00:00-05:00    TX  ...  Closed with explanation
# 10  2019-05-06T12:00:00-05:00    NY  ...  Closed with explanation
# 11  2019-03-14T12:00:00-05:00    TX  ...  Closed with explanation
# 14  2019-04-27T12:00:00-05:00    CA  ...  Closed with explanation
#
#                  company submitted_via       date_sent_to_company  \
# 1   JPMORGAN CHASE & CO.           Web  2019-05-01T12:00:00-05:00
# 2   JPMORGAN CHASE & CO.           Web  2019-04-02T12:00:00-05:00
# 10  JPMORGAN CHASE & CO.           Web  2019-05-06T12:00:00-05:00
# 11  JPMORGAN CHASE & CO.           Web  2019-03-15T12:00:00-05:00
# 14  JPMORGAN CHASE & CO.           Web  2019-04-27T12:00:00-05:00
#
#    company_public_response                                 sub_product timely  \
# 1                     None                            Credit card debt    Yes
# 2                     None  General-purpose credit card or charge card    Yes
# 10                    None              Other personal consumer report    Yes
# 11                    None                            Credit reporting    Yes
# 14                    None                            Checking account    Yes
#
#                               complaint_what_happened  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in xx/xx/2018 and...
# 10  chase card was reported on xx/xx/2019. however...
# 11  on xx/xx/2018, while trying to book a xxxx  xx...
# 14  my grand son give me check for {$1600.00} i de...
#
#                                            sub_issue consumer_consent_provided
# 1   Didn't receive enough information to verify debt          Consent provided
# 2              Problem with rewards from credit card          Consent provided
# 10               Information belongs to someone else          Consent provided
# 11               Information belongs to someone else          Consent provided
# 14      Funds not handled or disbursed as instructed          Consent provided
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Prepare the text for topic modeling
#
# Once you have removed all the blank complaints, you need to:
#
# * Make the text lowercase
# * Remove text in square brackets
# * Remove punctuation
# * Remove words containing numbers
#
#
# Once you have done these cleaning operations you need to perform the following:
# * Lemmatize the texts
# * Use POS tags to get relevant words from the texts.

# %%
# Write your function here to clean the text and remove all the unnecessary elements.
def clean_text(text):
    text = text.lower()
    text = re.sub("\[.*?]", "", text)
    text = re.sub(r'[^\w\s]','',text)
    text = re.sub("\w*\d\w*", "", text)
    return text

df.complaint_what_happened = pd.DataFrame(df.complaint_what_happened.apply(lambda x: clean_text(x)))

# %%
df.head(50)
# Out:
#                    index       type       id  score            tags zip_code  \
# 1    complaint-public-v2  complaint  3229299    0.0   Servicemember    319XX
# 2    complaint-public-v2  complaint  3199379    0.0            None    77069
# 10   complaint-public-v2  complaint  3233499    0.0            None    104XX
# 11   complaint-public-v2  complaint  3180294    0.0            None    750XX
# 14   complaint-public-v2  complaint  3224980    0.0            None    920XX
# 15   complaint-public-v2  complaint  3209411    0.0            None     None
# 17   complaint-public-v2  complaint  3331023    0.0            None    770XX
# 20   complaint-public-v2  complaint  3352857    0.0            None    207XX
# 21   complaint-public-v2  complaint  3226110    0.0   Servicemember    846XX
# 23   complaint-public-v2  complaint  3237765    0.0            None    330XX
# 24   complaint-public-v2  complaint  3200018    0.0            None    112XX
# 26   complaint-public-v2  complaint  3245661    0.0            None     None
# 27   complaint-public-v2  complaint  3200365    0.0            None    462XX
# 30   complaint-public-v2  complaint  3235343    0.0            None    946XX
# 32   complaint-public-v2  complaint  3236849    0.0            None    021XX
# 35   complaint-public-v2  complaint  3251082    0.0            None    770XX
# 40   complaint-public-v2  complaint  3357920    0.0            None    107XX
# 42   complaint-public-v2  complaint  3276682    0.0            None    606XX
# 43   complaint-public-v2  complaint  3264139    0.0            None    941XX
# 45   complaint-public-v2  complaint  3278394    0.0            None    891XX
# 48   complaint-public-v2  complaint  3138835    0.0            None    91006
# 50   complaint-public-v2  complaint  3282765    0.0  Older American     None
# 52   complaint-public-v2  complaint  3265926    0.0   Servicemember    333XX
# 57   complaint-public-v2  complaint  3198574    0.0            None     None
# 58   complaint-public-v2  complaint  3188608    0.0  Older American    77016
# 59   complaint-public-v2  complaint  3186663    0.0            None     None
# 63   complaint-public-v2  complaint  3265950    0.0   Servicemember    333XX
# 64   complaint-public-v2  complaint  3136481    0.0            None     None
# 65   complaint-public-v2  complaint  3195223    0.0            None    941XX
# 69   complaint-public-v2  complaint  3235148    0.0            None     None
# 73   complaint-public-v2  complaint  3219648    0.0            None    914XX
# 78   complaint-public-v2  complaint  3167556    0.0            None    945XX
# 81   complaint-public-v2  complaint  3227601    0.0            None    772XX
# 82   complaint-public-v2  complaint  3252343    0.0            None    460XX
# 83   complaint-public-v2  complaint  3205767    0.0            None    070XX
# 86   complaint-public-v2  complaint  3245126    0.0            None    809XX
# 88   complaint-public-v2  complaint  3194981    0.0            None    920XX
# 92   complaint-public-v2  complaint  3234417    0.0            None    917XX
# 93   complaint-public-v2  complaint  3222403    0.0   Servicemember    230XX
# 94   complaint-public-v2  complaint  3270769    0.0            None     None
# 95   complaint-public-v2  complaint  3156267    0.0            None    750XX
# 99   complaint-public-v2  complaint  3219989    0.0  Older American    113XX
# 100  complaint-public-v2  complaint  3200288    0.0            None    191XX
# 101  complaint-public-v2  complaint  3233517    0.0            None    112XX
# 103  complaint-public-v2  complaint  3249831    0.0            None    432XX
# 111  complaint-public-v2  complaint  3296168    0.0            None     None
# 115  complaint-public-v2  complaint  3220676    0.0            None    948XX
# 127  complaint-public-v2  complaint  2045718    0.0   Servicemember    09114
# 128  complaint-public-v2  complaint  3231169    0.0            None     None
# 129  complaint-public-v2  complaint  3264689    0.0            None     None
#
#     complaint_id                                              issue  \
# 1        3229299                    Written notification about debt
# 2        3199379                 Other features, terms, or problems
# 10       3233499               Incorrect information on your report
# 11       3180294               Incorrect information on your report
# 14       3224980                                Managing an account
# 15       3209411                        Improper use of your report
# 17       3331023                                 Closing an account
# 20       3352857                        Struggling to pay your loan
# 21       3226110                                      Fraud or scam
# 23       3237765               Incorrect information on your report
# 24       3200018           Problems at the end of the loan or lease
# 26       3245661                        Improper use of your report
# 27       3200365                                 Opening an account
# 30       3235343             Problem caused by your funds being low
# 32       3236849                            Trouble using your card
# 35       3251082                                 Opening an account
# 40       3357920  Problem with a lender or other company chargin...
# 42       3276682                                Managing an account
# 43       3264139                 Other features, terms, or problems
# 45       3278394  Problem with a lender or other company chargin...
# 48       3138835                        Improper use of your report
# 50       3282765    Problem with a purchase shown on your statement
# 52       3265926                                Managing an account
# 57       3198574                         Struggling to pay mortgage
# 58       3188608                                   Fees or interest
# 59       3186663                 Other features, terms, or problems
# 63       3265950                                Managing an account
# 64       3136481  Advertising and marketing, including promotion...
# 65       3195223  Advertising and marketing, including promotion...
# 69       3235148                                Managing an account
# 73       3219648                         Struggling to pay mortgage
# 78       3167556    Problem with a purchase shown on your statement
# 81       3227601           Problems at the end of the loan or lease
# 82       3252343                  Attempts to collect debt not owed
# 83       3205767                        Improper use of your report
# 86       3245126               Incorrect information on your report
# 88       3194981    Problem with a purchase shown on your statement
# 92       3234417  Took or threatened to take negative or legal a...
# 93       3222403    Problem with a purchase shown on your statement
# 94       3270769                 Other features, terms, or problems
# 95       3156267                            Trouble using your card
# 99       3219989                         Struggling to pay mortgage
# 100      3200288                        Improper use of your report
# 101      3233517             Problem caused by your funds being low
# 103      3249831                                 Opening an account
# 111      3296168    Problem with a purchase shown on your statement
# 115      3220676             Problem caused by your funds being low
# 127      2045718                         Managing the loan or lease
# 128      3231169               Incorrect information on your report
# 129      3264689    Problem with a purchase shown on your statement
#
#                  date_received state  ...                 company_response  \
# 1    2019-05-01T12:00:00-05:00    GA  ...          Closed with explanation
# 2    2019-04-02T12:00:00-05:00    TX  ...          Closed with explanation
# 10   2019-05-06T12:00:00-05:00    NY  ...          Closed with explanation
# 11   2019-03-14T12:00:00-05:00    TX  ...          Closed with explanation
# 14   2019-04-27T12:00:00-05:00    CA  ...          Closed with explanation
# 15   2019-04-11T12:00:00-05:00    LA  ...          Closed with explanation
# 17   2019-08-06T12:00:00-05:00    TX  ...          Closed with explanation
# 20   2019-08-24T12:00:00-05:00    MD  ...          Closed with explanation
# 21   2019-04-29T12:00:00-05:00    UT  ...          Closed with explanation
# 23   2019-05-09T12:00:00-05:00    FL  ...  Closed with non-monetary relief
# 24   2019-04-03T12:00:00-05:00    NY  ...          Closed with explanation
# 26   2019-05-17T12:00:00-05:00    AL  ...  Closed with non-monetary relief
# 27   2019-04-03T12:00:00-05:00    IN  ...      Closed with monetary relief
# 30   2019-05-07T12:00:00-05:00    CA  ...      Closed with monetary relief
# 32   2019-05-09T12:00:00-05:00    MA  ...  Closed with non-monetary relief
# 35   2019-05-22T12:00:00-05:00    TX  ...          Closed with explanation
# 40   2019-08-29T12:00:00-05:00    NY  ...          Closed with explanation
# 42   2019-06-16T12:00:00-05:00    IL  ...          Closed with explanation
# 43   2019-06-04T12:00:00-05:00    CA  ...          Closed with explanation
# 45   2019-06-18T12:00:00-05:00    NV  ...          Closed with explanation
# 48   2019-01-31T12:00:00-05:00    CA  ...          Closed with explanation
# 50   2019-06-21T12:00:00-05:00    WI  ...          Closed with explanation
# 52   2019-06-06T12:00:00-05:00    FL  ...          Closed with explanation
# 57   2019-04-02T12:00:00-05:00    WA  ...          Closed with explanation
# 58   2019-03-22T12:00:00-05:00    TX  ...          Closed with explanation
# 59   2019-03-21T12:00:00-05:00  None  ...          Closed with explanation
# 63   2019-06-06T12:00:00-05:00    FL  ...          Closed with explanation
# 64   2019-01-29T12:00:00-05:00    TN  ...          Closed with explanation
# 65   2019-03-29T12:00:00-05:00    CA  ...          Closed with explanation
# 69   2019-05-07T12:00:00-05:00    OK  ...          Closed with explanation
# 73   2019-04-23T12:00:00-05:00    CA  ...          Closed with explanation
# 78   2019-03-02T12:00:00-05:00    CA  ...      Closed with monetary relief
# 81   2019-04-30T12:00:00-05:00    TX  ...          Closed with explanation
# 82   2019-05-23T12:00:00-05:00    IN  ...      Closed with monetary relief
# 83   2019-04-09T12:00:00-05:00    NJ  ...          Closed with explanation
# 86   2019-05-16T12:00:00-05:00    CO  ...          Closed with explanation
# 88   2019-03-29T12:00:00-05:00    CA  ...          Closed with explanation
# 92   2019-05-07T12:00:00-05:00    CA  ...      Closed with monetary relief
# 93   2019-04-25T12:00:00-05:00    VA  ...          Closed with explanation
# 94   2019-06-11T12:00:00-05:00    VA  ...      Closed with monetary relief
# 95   2019-02-19T12:00:00-05:00    TX  ...  Closed with non-monetary relief
# 99   2019-04-23T12:00:00-05:00    NY  ...          Closed with explanation
# 100  2019-04-03T12:00:00-05:00    PA  ...  Closed with non-monetary relief
# 101  2019-05-06T12:00:00-05:00    NY  ...          Closed with explanation
# 103  2019-05-22T12:00:00-05:00    OH  ...      Closed with monetary relief
# 111  2019-07-04T12:00:00-05:00    FL  ...          Closed with explanation
# 115  2019-04-23T12:00:00-05:00    CA  ...      Closed with monetary relief
# 127  2016-08-04T12:00:00-05:00    AE  ...      Closed with monetary relief
# 128  2019-05-03T12:00:00-05:00    CT  ...  Closed with non-monetary relief
# 129  2019-06-05T12:00:00-05:00    CO  ...          Closed with explanation
#
#                   company submitted_via       date_sent_to_company  \
# 1    JPMORGAN CHASE & CO.           Web  2019-05-01T12:00:00-05:00
# 2    JPMORGAN CHASE & CO.           Web  2019-04-02T12:00:00-05:00
# 10   JPMORGAN CHASE & CO.           Web  2019-05-06T12:00:00-05:00
# 11   JPMORGAN CHASE & CO.           Web  2019-03-15T12:00:00-05:00
# 14   JPMORGAN CHASE & CO.           Web  2019-04-27T12:00:00-05:00
# 15   JPMORGAN CHASE & CO.           Web  2019-04-11T12:00:00-05:00
# 17   JPMORGAN CHASE & CO.           Web  2019-08-06T12:00:00-05:00
# 20   JPMORGAN CHASE & CO.           Web  2019-08-24T12:00:00-05:00
# 21   JPMORGAN CHASE & CO.           Web  2019-04-29T12:00:00-05:00
# 23   JPMORGAN CHASE & CO.           Web  2019-05-09T12:00:00-05:00
# 24   JPMORGAN CHASE & CO.           Web  2019-04-03T12:00:00-05:00
# 26   JPMORGAN CHASE & CO.           Web  2019-05-17T12:00:00-05:00
# 27   JPMORGAN CHASE & CO.           Web  2019-04-03T12:00:00-05:00
# 30   JPMORGAN CHASE & CO.           Web  2019-05-07T12:00:00-05:00
# 32   JPMORGAN CHASE & CO.           Web  2019-05-09T12:00:00-05:00
# 35   JPMORGAN CHASE & CO.           Web  2019-05-22T12:00:00-05:00
# 40   JPMORGAN CHASE & CO.           Web  2019-08-29T12:00:00-05:00
# 42   JPMORGAN CHASE & CO.           Web  2019-06-16T12:00:00-05:00
# 43   JPMORGAN CHASE & CO.           Web  2019-06-04T12:00:00-05:00
# 45   JPMORGAN CHASE & CO.           Web  2019-06-18T12:00:00-05:00
# 48   JPMORGAN CHASE & CO.           Web  2019-01-31T12:00:00-05:00
# 50   JPMORGAN CHASE & CO.           Web  2019-06-21T12:00:00-05:00
# 52   JPMORGAN CHASE & CO.           Web  2019-06-06T12:00:00-05:00
# 57   JPMORGAN CHASE & CO.           Web  2019-04-02T12:00:00-05:00
# 58   JPMORGAN CHASE & CO.           Web  2019-03-22T12:00:00-05:00
# 59   JPMORGAN CHASE & CO.           Web  2019-03-21T12:00:00-05:00
# 63   JPMORGAN CHASE & CO.           Web  2019-06-06T12:00:00-05:00
# 64   JPMORGAN CHASE & CO.           Web  2019-01-29T12:00:00-05:00
# 65   JPMORGAN CHASE & CO.           Web  2019-03-29T12:00:00-05:00
# 69   JPMORGAN CHASE & CO.           Web  2019-05-07T12:00:00-05:00
# 73   JPMORGAN CHASE & CO.           Web  2019-04-26T12:00:00-05:00
# 78   JPMORGAN CHASE & CO.           Web  2019-03-02T12:00:00-05:00
# 81   JPMORGAN CHASE & CO.           Web  2019-05-09T12:00:00-05:00
# 82   JPMORGAN CHASE & CO.           Web  2019-05-23T12:00:00-05:00
# 83   JPMORGAN CHASE & CO.           Web  2019-04-09T12:00:00-05:00
# 86   JPMORGAN CHASE & CO.           Web  2019-05-23T12:00:00-05:00
# 88   JPMORGAN CHASE & CO.           Web  2019-03-29T12:00:00-05:00
# 92   JPMORGAN CHASE & CO.           Web  2019-05-07T12:00:00-05:00
# 93   JPMORGAN CHASE & CO.           Web  2019-04-25T12:00:00-05:00
# 94   JPMORGAN CHASE & CO.           Web  2019-06-11T12:00:00-05:00
# 95   JPMORGAN CHASE & CO.           Web  2019-02-19T12:00:00-05:00
# 99   JPMORGAN CHASE & CO.           Web  2019-04-23T12:00:00-05:00
# 100  JPMORGAN CHASE & CO.           Web  2019-04-03T12:00:00-05:00
# 101  JPMORGAN CHASE & CO.           Web  2019-05-06T12:00:00-05:00
# 103  JPMORGAN CHASE & CO.           Web  2019-05-22T12:00:00-05:00
# 111  JPMORGAN CHASE & CO.           Web  2019-07-04T12:00:00-05:00
# 115  JPMORGAN CHASE & CO.           Web  2019-04-23T12:00:00-05:00
# 127  JPMORGAN CHASE & CO.           Web  2016-08-04T12:00:00-05:00
# 128  JPMORGAN CHASE & CO.           Web  2019-05-03T12:00:00-05:00
# 129  JPMORGAN CHASE & CO.           Web  2019-06-05T12:00:00-05:00
#
#     company_public_response                                 sub_product  \
# 1                      None                            Credit card debt
# 2                      None  General-purpose credit card or charge card
# 10                     None              Other personal consumer report
# 11                     None                            Credit reporting
# 14                     None                            Checking account
# 15                     None                            Credit reporting
# 17                     None                            Checking account
# 20                     None                                        Loan
# 21                     None                Domestic (US) money transfer
# 23                     None  General-purpose credit card or charge card
# 24                     None                                        Loan
# 26                     None                            Credit reporting
# 27                     None                            Checking account
# 30                     None                            Checking account
# 32                     None  General-purpose credit card or charge card
# 35                     None                             Savings account
# 40                     None                            Checking account
# 42                     None                            Checking account
# 43                     None  General-purpose credit card or charge card
# 45                     None                            Checking account
# 48                     None                            Checking account
# 50                     None  General-purpose credit card or charge card
# 52                     None                            Checking account
# 57                     None                  Conventional home mortgage
# 58                     None  General-purpose credit card or charge card
# 59                     None  General-purpose credit card or charge card
# 63                     None                            Checking account
# 64                     None  General-purpose credit card or charge card
# 65                     None  General-purpose credit card or charge card
# 69                     None                            Checking account
# 73                     None  Home equity loan or line of credit (HELOC)
# 78                     None  General-purpose credit card or charge card
# 81                     None                                        Loan
# 82                     None                            Credit card debt
# 83                     None                            Credit reporting
# 86                     None                        Private student loan
# 88                     None  General-purpose credit card or charge card
# 92                     None                               I do not know
# 93                     None  General-purpose credit card or charge card
# 94                     None  General-purpose credit card or charge card
# 95                     None  General-purpose credit card or charge card
# 99                     None                  Conventional home mortgage
# 100                    None                            Credit reporting
# 101                    None                            Checking account
# 103                    None                            Checking account
# 111                    None  General-purpose credit card or charge card
# 115                    None                            Checking account
# 127                    None                                Vehicle loan
# 128                    None                            Credit reporting
# 129                    None  General-purpose credit card or charge card
#
#     timely                            complaint_what_happened  \
# 1      Yes  good morning my name is xxxx xxxx and i apprec...
# 2      Yes  i upgraded my xxxx xxxx card in  and was told ...
# 10     Yes  chase card was reported on  however fraudulent...
# 11     Yes  on  while trying to book a xxxx  xxxx  ticket ...
# 14     Yes  my grand son give me check for  i deposit it i...
# 15     Yes                      can you please remove inquiry
# 17     Yes  with out notice jp morgan chase restricted my ...
# 20     Yes  during the summer months i experience a declin...
# 21     Yes  on xxxx  i made a  payment to an online retail...
# 23     Yes  i have a chase credit card which is incorrectl...
# 24     Yes  mishandling of this account by chase auto and ...
# 26     Yes  i have reached out to xxxx several times in at...
# 27     Yes  i opened an account with chase bank on xxxx an...
# 30     Yes  to whom it may concern chase bank charged wron...
# 32     Yes  my chase amazon card was declined for a cateri...
# 35     Yes  i opened the saving account for the  bonus i w...
# 40     Yes  xxxx xxxx a sofa love seat table and chairs an...
# 42     Yes  my card went missing and i didnt realize it un...
# 43     Yes  chase sent me an email today with the innocuou...
# 45     Yes  i made a purchase with xxxx xxxx xxxx on  in t...
# 48     Yes  jp morgan chase bank please answer the followi...
# 50     Yes  i am a senior citizen that has been scammed by...
# 52     Yes  my roommate was stealing my chase debit card a...
# 57     Yes  i have been trying to do a loan modification w...
# 58     Yes  i made a purchase of  on xxxxxxxx i made payme...
# 59     Yes  i currently have over xxxx chase ultimate rewa...
# 63     Yes  i tried to send almost  at xxxx and the transa...
# 64     Yes  chase is marketing credit cards to those of us...
# 65     Yes  i opened the chasexxxx xxxx rewards credit car...
# 69     Yes  someone called stating i had felony committed ...
# 73     Yes  i have wired through one of chase branches in ...
# 78     Yes  my dispute is for not receiving services liste...
# 81     Yes  i bought a new xxxx xxxx on xxxxxxxx from xxxx...
# 82     Yes  i recently called to ask chase bank why they r...
# 83     Yes  unknown inquire reported on my credit bureau s...
# 86     Yes  a student loan with chase bank they sold there...
# 88     Yes  i preordered an item on xxxxxxxx and paid  wit...
# 92     Yes  in  several transactions on my chase checking ...
# 93     Yes  on  we purchased a service with xxxx xxxx xxxx...
# 94     Yes  i am writing you to file a complaint about an ...
# 95     Yes  on  i paid off my chase credit card in full an...
# 99     Yes  my name is xxxx xxxx i have missed a payment i...
# 100    Yes  i have contacted both chase bank and xxxx xxxx...
# 101    Yes  i purchase is an airline ticket on xxxxxxxx an...
# 103    Yes  on xxxxxxxx i received an advertisement via em...
# 111    Yes  i advised chase of the billing error for goods...
# 115    Yes  multiple times with the latest being xxxxxxxx ...
# 127    Yes  i am xxxx military member  xxxx  with the xxxx...
# 128    Yes  i have contacted jp morgan chase as well as xx...
# 129    Yes  this complaint is a follow up regarding a comp...
#
#                                              sub_issue  \
# 1     Didn't receive enough information to verify debt
# 2                Problem with rewards from credit card
# 10                 Information belongs to someone else
# 11                 Information belongs to someone else
# 14        Funds not handled or disbursed as instructed
# 15   Credit inquiries on your report that you don't...
# 17              Funds not received from closed account
# 20                    Denied request to lower payments
# 21                                                None
# 23                       Account information incorrect
# 24      Problem while selling or giving up the vehicle
# 26   Credit inquiries on your report that you don't...
# 27           Didn't receive terms that were advertised
# 30                       Overdrafts and overdraft fees
# 32                    Can't use card to make purchases
# 35           Didn't receive terms that were advertised
# 40                      Transaction was not authorized
# 42                   Problem using a debit or ATM card
# 43             Credit card company forcing arbitration
# 45                      Transaction was not authorized
# 48       Reporting company used your report improperly
# 50   Credit card company isn't resolving a dispute ...
# 52                            Deposits and withdrawals
# 57                                                None
# 58                           Charged too much interest
# 59               Problem with rewards from credit card
# 63                            Deposits and withdrawals
# 64   Confusing or misleading advertising about the ...
# 65      Didn't receive advertised or promotional terms
# 69                   Problem using a debit or ATM card
# 73                                                None
# 78   Credit card company isn't resolving a dispute ...
# 81   Unable to receive car title or other problem a...
# 82                                       Debt was paid
# 83   Credit inquiries on your report that you don't...
# 86                            Account status incorrect
# 88   Credit card company isn't resolving a dispute ...
# 92   Threatened or suggested your credit would be d...
# 93   Credit card company isn't resolving a dispute ...
# 94               Problem with rewards from credit card
# 95                    Can't use card to make purchases
# 99                                                None
# 100  Credit inquiries on your report that you don't...
# 101                Bounced checks or returned payments
# 103          Didn't receive terms that were advertised
# 111  Credit card company isn't resolving a dispute ...
# 115                      Overdrafts and overdraft fees
# 127                                               None
# 128                           Account status incorrect
# 129  Credit card company isn't resolving a dispute ...
#
#     consumer_consent_provided
# 1            Consent provided
# 2            Consent provided
# 10           Consent provided
# 11           Consent provided
# 14           Consent provided
# 15           Consent provided
# 17           Consent provided
# 20           Consent provided
# 21           Consent provided
# 23           Consent provided
# 24           Consent provided
# 26           Consent provided
# 27           Consent provided
# 30           Consent provided
# 32           Consent provided
# 35           Consent provided
# 40           Consent provided
# 42           Consent provided
# 43           Consent provided
# 45           Consent provided
# 48           Consent provided
# 50           Consent provided
# 52           Consent provided
# 57           Consent provided
# 58           Consent provided
# 59           Consent provided
# 63           Consent provided
# 64           Consent provided
# 65           Consent provided
# 69           Consent provided
# 73           Consent provided
# 78           Consent provided
# 81           Consent provided
# 82           Consent provided
# 83           Consent provided
# 86           Consent provided
# 88           Consent provided
# 92           Consent provided
# 93           Consent provided
# 94           Consent provided
# 95           Consent provided
# 99           Consent provided
# 100          Consent provided
# 101          Consent provided
# 103          Consent provided
# 111          Consent provided
# 115          Consent provided
# 127          Consent provided
# 128          Consent provided
# 129          Consent provided
#
# [50 rows x 22 columns]

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\malayaku\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\malayaku\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#Write your function to Lemmatize the texts
def lemmatizer(text):        
    sent = [wordnet_lemmatizer.lemmatize(word) for word in text if not word in set(stopwords.words('english'))]
    return " ".join(sent)

# %%
text = "I got the work"
#print(wordnet_lemmatizer.lemmatize("doing"))
print(lemmatizer(text))
# Out:
# I   g   h e   w r k

# %%
df['Lema'] =  df.complaint_what_happened.apply(lambda x: lemmatizer(x))

# %%
#Create a dataframe('df_clean') that will have only the complaints and the lemmatized complaints 
df_clean=df[['complaint_what_happened','Lema']]

# %%
df_clean
# Out:
#                                  complaint_what_happened  \
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in  and was told ...
# 10     chase card was reported on  however fraudulent...
# 11     on  while trying to book a xxxx  xxxx  ticket ...
# 14     my grand son give me check for  i deposit it i...
# ...                                                  ...
# 78303  after being a chase card customer for well ove...
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for  yrs ive had ch...
# 78312  roughly  years ago i closed out my accounts wi...
#
#                                                     Lema
# 1      g   r n n g     n e     x x x x   x x x x   n ...
# 2        u p g r e     x x x x   x x x x   c r   n   ...
# 10     c h e   c r   w   r e p r e   n     h w e v e ...
# 11     n     w h l e   r n g     b k     x x x x     ...
# 14       g r n   n   g v e   e   c h e c k   f r     ...
# ...                                                  ...
# 78303  f e r   b e n g     c h e   c r   c u e r   f ...
# 78309  n   w e n e   x x x x x x x x     c l l e   c ...
# 78310      n   f l r   w h   x x x x   p   n     n   ...
# 78311    h v e   h   f l w l e   c r e   f r     r   ...
# 78312  r u g h l     e r   g     c l e   u     c c u ...
#
# [21072 rows x 2 columns]

# %%
df_clean
# Out:
#                                  complaint_what_happened  \
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in  and was told ...
# 10     chase card was reported on  however fraudulent...
# 11     on  while trying to book a xxxx  xxxx  ticket ...
# 14     my grand son give me check for  i deposit it i...
# ...                                                  ...
# 78303  after being a chase card customer for well ove...
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for  yrs ive had ch...
# 78312  roughly  years ago i closed out my accounts wi...
#
#                                                     Lema
# 1      g   r n n g     n e     x x x x   x x x x   n ...
# 2        u p g r e     x x x x   x x x x   c r   n   ...
# 10     c h e   c r   w   r e p r e   n     h w e v e ...
# 11     n     w h l e   r n g     b k     x x x x     ...
# 14       g r n   n   g v e   e   c h e c k   f r     ...
# ...                                                  ...
# 78303  f e r   b e n g     c h e   c r   c u e r   f ...
# 78309  n   w e n e   x x x x x x x x     c l l e   c ...
# 78310      n   f l r   w h   x x x x   p   n     n   ...
# 78311    h v e   h   f l w l e   c r e   f r     r   ...
# 78312  r u g h l     e r   g     c l e   u     c c u ...
#
# [21072 rows x 2 columns]

# %%
#Write your function to extract the POS tags NN (Only NN tagged words will remain)

# %%
#The clean dataframe should now contain the raw complaint, lemmatized complaint and the complaint after removing POS tags.
df_clean

# %% [markdown]
# ## Exploratory data analysis to get familiar with the data.
#
# Write the code in this task to perform the following:
#
# *   Visualise the data according to the 'Complaint' character length
# *   Using a word cloud find the top 40 words by frequency among all the articles after processing the text
# *   Find the top unigrams,bigrams and trigrams by frequency among all the complaints after processing the text. ‘

# %%
# Write your code here to visualise the data according to the 'Complaint' character length

# %% [markdown]
# #### Find the top 40 words by frequency among all the articles after processing the text.

# %%
#Using a word cloud find the top 40 words by frequency among all the articles after processing the text

# %%
#Removing -PRON- from the text corpus
df_clean['Complaint_clean'] = df_clean['complaint_POS_removed'].str.replace('-PRON-', '')

# %% [markdown]
# #### Find the top unigrams,bigrams and trigrams by frequency among all the complaints after processing the text.

# %%
#Write your code here to find the top 30 unigram frequency among the complaints in the cleaned datafram(df_clean).

# %%
#Print the top 10 words in the unigram frequency

# %%
#Write your code here to find the top 30 bigram frequency among the complaints in the cleaned datafram(df_clean).

# %%
#Print the top 10 words in the bigram frequency

# %%
#Write your code here to find the top 30 trigram frequency among the complaints in the cleaned datafram(df_clean).

# %%
#Print the top 10 words in the trigram frequency

# %% [markdown]
# ## The personal details of customer has been masked in the dataset with xxxx. Let's remove the masked text as this will be of no use for our analysis

# %%
df_clean['Complaint_clean'] = df_clean['Complaint_clean'].str.replace('xxxx','')

# %%
#All masked texts has been removed
df_clean

# %% [markdown]
# ## Feature Extraction
# Convert the raw texts to a matrix of TF-IDF features
#
# **max_df** is used for removing terms that appear too frequently, also known as "corpus-specific stop words"
# max_df = 0.95 means "ignore terms that appear in more than 95% of the complaints"
#
# **min_df** is used for removing terms that appear too infrequently
# min_df = 2 means "ignore terms that appear in less than 2 complaints"

# %%
#Write your code here to initialise the TfidfVectorizer

# %% [markdown]
# #### Create a document term matrix using fit_transform
#
# The contents of a document term matrix are tuples of (complaint_id,token_id) tf-idf score:
# The tuples that are not there have a tf-idf score of 0

# %%
#Write your code here to create the Document Term Matrix by transforming the complaints column present in df_clean.

# %% [markdown]
# ## Topic Modelling using NMF
#
# Non-Negative Matrix Factorization (NMF) is an unsupervised technique so there are no labeling of topics that the model will be trained on. The way it works is that, NMF decomposes (or factorizes) high-dimensional vectors into a lower-dimensional representation. These lower-dimensional vectors are non-negative which also means their coefficients are non-negative.
#
# In this task you have to perform the following:
#
# * Find the best number of clusters
# * Apply the best number to create word clusters
# * Inspect & validate the correction of each cluster wrt the complaints
# * Correct the labels if needed
# * Map the clusters to topics/cluster names

# %%
from sklearn.decomposition import NMF

# %% [markdown]
# ## Manual Topic Modeling
# You need to do take the trial & error approach to find the best num of topics for your NMF model.
#
# The only parameter that is required is the number of components i.e. the number of topics we want. This is the most crucial step in the whole topic modeling process and will greatly affect how good your final topics are.

# %%
#Load your nmf_model with the n_components i.e 5
num_topics = #write the value you want to test out

#keep the random_state =40
nmf_model = #write your code here

# %%
nmf_model.fit(dtm)
len(tfidf.get_feature_names())

# %%
#Print the Top15 words for each of the topics

# %%
#Create the best topic for each complaint in terms of integer value 0,1,2,3 & 4

# %%
#Assign the best topic to each of the cmplaints in Topic Column

df_clean['Topic'] = #write your code to assign topics to each rows.

# %%
df_clean.head()

# %%
#Print the first 5 Complaint for each of the Topics
df_clean=df_clean.groupby('Topic').head(5)
df_clean.sort_values('Topic')

# %% [markdown]
# #### After evaluating the mapping, if the topics assigned are correct then assign these names to the relevant topic:
# * Bank Account services
# * Credit card or prepaid card
# * Theft/Dispute Reporting
# * Mortgage/Loan
# * Others

# %%
#Create the dictionary of Topic names and Topics

Topic_names = {   }
#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
df_clean

# %% [markdown]
# ## Supervised model to predict any new complaints to the relevant Topics.
#
# You have now build the model to create the topics for each complaints.Now in the below section you will use them to classify any new complaints.
#
# Since you will be using supervised learning technique we have to convert the topic names to numbers(numpy arrays only understand numbers)

# %%
#Create the dictionary again of Topic names and Topics

Topic_names = {   }
#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
df_clean

# %%
#Keep the columns"complaint_what_happened" & "Topic" only in the new dataframe --> training_data
training_data=

# %%
training_data

# %% [markdown]
# ####Apply the supervised models on the training data created. In this process, you have to do the following:
# * Create the vector counts using Count Vectoriser
# * Transform the word vecotr to tf-idf
# * Create the train & test data using the train_test_split on the tf-idf & topics

# %%
#Write your code to get the Vector count


#Write your code here to transform the word vector to tf-idf

# %% [markdown]
# You have to try atleast 2 models on the train & test data from these options:
# * Logistic regression
# * Decision Tree
# * Random Forest
# * Naive Bayes (optional)
#
# **Using the required evaluation metrics judge the tried models and select the ones performing the best**

# %%
# Write your code here to build any 3 models and evaluate them using the required metrics
